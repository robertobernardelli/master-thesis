# %%
from network import Network
import networkx as nx

network = Network(100)

# %%
# infect one random agent

network.agents[25].infected = True

# %%
network.run_simulation(100)
# Out:
# Step 0; infected: 1
# Agent #Agent #25 infected agent #Agent #55
# Agent #Agent #25 infected agent #Agent #30
# Agent #Agent #25 infected agent #Agent #75
# Agent #Agent #55 infected agent #Agent #33
# Agent #Agent #33 infected agent #Agent #62
# Agent #Agent #33 infected agent #Agent #89
# Agent #Agent #33 infected agent #Agent #10
# Agent #Agent #55 infected agent #Agent #34
# Agent #Agent #34 infected agent #Agent #41
# Agent #Agent #34 infected agent #Agent #63
# Agent #Agent #33 infected agent #Agent #35
# Agent #Agent #30 infected agent #Agent #38
# Agent #Agent #38 infected agent #Agent #13
# Agent #Agent #38 infected agent #Agent #79
# Agent #Agent #30 infected agent #Agent #46
# Agent #Agent #35 infected agent #Agent #47
# Agent #Agent #75 infected agent #Agent #52
# Agent #Agent #52 infected agent #Agent #86
# Agent #Agent #35 infected agent #Agent #53
# Agent #Agent #55 infected agent #Agent #87
# Agent #Agent #79 infected agent #Agent #56
# Agent #Agent #79 infected agent #Agent #60
# Agent #Agent #62 infected agent #Agent #88
# Agent #Agent #62 infected agent #Agent #8
# Agent #Agent #62 infected agent #Agent #37
# Agent #Agent #63 infected agent #Agent #78
# Agent #Agent #63 infected agent #Agent #81
# Agent #Agent #53 infected agent #Agent #65
# Agent #Agent #65 infected agent #Agent #18
# Agent #Agent #37 infected agent #Agent #68
# Agent #Agent #30 infected agent #Agent #71
# Agent #Agent #18 infected agent #Agent #80
# Agent #Agent #56 infected agent #Agent #83
# Agent #Agent #10 infected agent #Agent #90
# Agent #Agent #13 infected agent #Agent #93
# Step 1; infected: 36
# Agent #Agent #55 infected agent #Agent #1
# Agent #Agent #86 infected agent #Agent #2
# Agent #Agent #2 infected agent #Agent #91
# Agent #Agent #2 infected agent #Agent #3
# Agent #Agent #2 infected agent #Agent #24
# Agent #Agent #2 infected agent #Agent #28
# Agent #Agent #2 infected agent #Agent #43
# Agent #Agent #2 infected agent #Agent #59
# Agent #Agent #2 infected agent #Agent #99
# Agent #Agent #3 infected agent #Agent #5
# Agent #Agent #3 infected agent #Agent #23
# Agent #Agent #5 infected agent #Agent #69
# Agent #Agent #5 infected agent #Agent #36
# Agent #Agent #13 infected agent #Agent #7
# Agent #Agent #7 infected agent #Agent #84
# Agent #Agent #8 infected agent #Agent #11
# Agent #Agent #8 infected agent #Agent #48
# Agent #Agent #18 infected agent #Agent #9
# Agent #Agent #10 infected agent #Agent #16
# Agent #Agent #11 infected agent #Agent #20
# Agent #Agent #13 infected agent #Agent #14
# Agent #Agent #13 infected agent #Agent #15
# Agent #Agent #14 infected agent #Agent #26
# Agent #Agent #28 infected agent #Agent #17
# Agent #Agent #20 infected agent #Agent #97
# Agent #Agent #36 infected agent #Agent #22
# Agent #Agent #1 infected agent #Agent #27
# Agent #Agent #27 infected agent #Agent #77
# Agent #Agent #1 infected agent #Agent #32
# Agent #Agent #34 infected agent #Agent #54
# Agent #Agent #35 infected agent #Agent #45
# Agent #Agent #36 infected agent #Agent #51
# Agent #Agent #41 infected agent #Agent #44
# Agent #Agent #59 infected agent #Agent #42
# Agent #Agent #44 infected agent #Agent #4
# Agent #Agent #48 infected agent #Agent #66
# Agent #Agent #54 infected agent #Agent #19
# Agent #Agent #86 infected agent #Agent #73
# Agent #Agent #7 infected agent #Agent #82
# Agent #Agent #83 infected agent #Agent #98
# Agent #Agent #1 infected agent #Agent #85
# Agent #Agent #91 infected agent #Agent #96
# Step 2; infected: 78
# Agent #Agent #5 infected agent #Agent #0
# Agent #Agent #0 infected agent #Agent #29
# Agent #Agent #0 infected agent #Agent #31
# Agent #Agent #3 infected agent #Agent #58
# Agent #Agent #3 infected agent #Agent #76
# Agent #Agent #3 infected agent #Agent #95
# Agent #Agent #3 infected agent #Agent #72
# Agent #Agent #3 infected agent #Agent #21
# Agent #Agent #3 infected agent #Agent #92
# Agent #Agent #5 infected agent #Agent #49
# Agent #Agent #31 infected agent #Agent #70
# Agent #Agent #36 infected agent #Agent #50
# Agent #Agent #3 infected agent #Agent #61
# Agent #Agent #61 infected agent #Agent #74
# Agent #Agent #4 infected agent #Agent #67
# Step 3; infected: 93
# Agent #Agent #0 infected agent #Agent #6
# Agent #Agent #2 infected agent #Agent #39
# Agent #Agent #3 infected agent #Agent #40
# Agent #Agent #6 infected agent #Agent #57
# Agent #Agent #7 infected agent #Agent #64
# Agent #Agent #0 infected agent #Agent #12
# Agent #Agent #68 infected agent #Agent #94
# Step 4; infected: 100
# Step 5; infected: 100
# Step 6; infected: 100
# Step 7; infected: 100
# Step 8; infected: 100
# Step 9; infected: 100
# Step 10; infected: 100
# Step 11; infected: 100
# Step 12; infected: 100
# Step 13; infected: 100
# Step 14; infected: 100
# Step 15; infected: 100
# Step 16; infected: 100
# Step 17; infected: 100
# Step 18; infected: 100
# Step 19; infected: 100
# Step 20; infected: 100
# Step 21; infected: 100
# Step 22; infected: 100
# Step 23; infected: 100
# Step 24; infected: 100
# Step 25; infected: 100
# Step 26; infected: 100
# Step 27; infected: 100
# Step 28; infected: 100
# Step 29; infected: 100
# Step 30; infected: 100
# Step 31; infected: 100
# Step 32; infected: 100
# Step 33; infected: 100
# Step 34; infected: 100
# Step 35; infected: 100
# Step 36; infected: 100
# Step 37; infected: 100
# Step 38; infected: 100
# Step 39; infected: 100
# Step 40; infected: 100
# Step 41; infected: 100
# Step 42; infected: 100
# Step 43; infected: 100
# Step 44; infected: 100
# Step 45; infected: 100
# Step 46; infected: 100
# Step 47; infected: 100
# Step 48; infected: 100
# Step 49; infected: 100
# Step 50; infected: 100
# Step 51; infected: 100
# Step 52; infected: 100
# Step 53; infected: 100
# Step 54; infected: 100
# Step 55; infected: 100
# Step 56; infected: 100
# Step 57; infected: 100
# Step 58; infected: 100
# Step 59; infected: 100
# Step 60; infected: 100
# Step 61; infected: 100
# Step 62; infected: 100
# Step 63; infected: 100
# Step 64; infected: 100
# Step 65; infected: 100
# Step 66; infected: 100
# Step 67; infected: 100
# Step 68; infected: 100
# Step 69; infected: 100
# Step 70; infected: 100
# Step 71; infected: 100
# Step 72; infected: 100
# Step 73; infected: 100
# Step 74; infected: 100
# Step 75; infected: 100
# Step 76; infected: 100
# Step 77; infected: 100
# Step 78; infected: 100
# Step 79; infected: 100
# Step 80; infected: 100
# Step 81; infected: 100
# Step 82; infected: 100
# Step 83; infected: 100
# Step 84; infected: 100
# Step 85; infected: 100
# Step 86; infected: 100
# Step 87; infected: 100
# Step 88; infected: 100
# Step 89; infected: 100
# Step 90; infected: 100
# Step 91; infected: 100
# Step 92; infected: 100
# Step 93; infected: 100
# Step 94; infected: 100
# Step 95; infected: 100
# Step 96; infected: 100
# Step 97; infected: 100
# Step 98; infected: 100
# Step 99; infected: 100

# %%
nx.draw(network.household_network, with_labels = True)

# %%
network.agents[3].household_connections
# Out:
# [Agent #0, Agent #1, Agent #14, Agent #17, Agent #24, Agent #27, Agent #40]

# %%
nx.draw(network.friendship_network, with_labels = True)

# %%
network.agents[9].friend_connections
# Out:
# [Agent #0, Agent #3]
